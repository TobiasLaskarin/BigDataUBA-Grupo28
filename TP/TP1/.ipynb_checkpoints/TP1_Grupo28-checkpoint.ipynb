# %% [markdown]
# # Big Data y Machine Learning (UBA) -  2025
#
# ## Trabajo Práctico 1: Jugando con APIs y WebScraping

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Viernes 4 de Abril a las 13:00 hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- a mi correo 25RO35480961@campus.economicas.uba.ar. Usar de asunto de email <i>"Big Data - TP 1 - Grupo #"</i> y nombrar el archivo <i>"TP1_Grupo #"</i> donde # es el número de grupo que le fue asignado.
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.
# - En resumen, la carpeta del repositorio debe incluir:
#     - El codigo
#     - Un documento Word (Parte A) donde esten las figuras y una breve descripción de las mismas.
#     - El excel con los links webscrappeados (Parte B)

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1 - Jugando con APIs
# Usando la API del Banco Mundial [link](https://wbdata.readthedocs.io/en/stable/) , obtener dos series de indicadores para dos paises a elección en una consulta de búsqueda. Pueden buscar serie de indicadores de su interés.

# %%
# Importamos los modulos con las herramientas necesarias para el tp
import wbdata
import pandas as pd
import matplotlib.pyplot as plt
import os
#Encontramos los id de los paises que vamos a utilizar
wbdata.get_countries(query="china"), wbdata.get_countries(query="australia")
# Out:
# (id    name
#  ----  --------------------
#  CHN   China
#  HKG   Hong Kong SAR, China
#  MAC   Macao SAR, China,
#  id    name
#  ----  ---------
#  AUS   Australia)

# %%
#Buscamos los parametros de la base de datos
wbdata.get_sources()
# Out:
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Financial Inclusion
#   29  The Atlas of Social Protection: Indicators of Resilience and Equity
#   30  Exporter Dynamics Database – Indicators at Country-Year Level
#   31  Country Policy and Institutional Assessment
#   32  Global Financial Development
#   33  G20 Financial Inclusion Indicators
#   34  Global Partnership for Education
#   35  Sustainable Energy for All
#   37  LAC Equity Lab
#   38  Subnational Poverty
#   39  Health Nutrition and Population Statistics by Wealth Quintile
#   40  Population estimates and projections
#   41  Country Partnership Strategy for India (FY2013 - 17)
#   43  Adjusted Net Savings
#   45  Indonesia Database for Policy and Economic Research
#   46  Sustainable Development Goals
#   50  Subnational Population
#   54  Joint External Debt Hub
#   57  WDI Database Archives
#   58  Universal Health Coverage
#   59  Wealth Accounts
#   60  Economic Fitness
#   61  PPPs Regulatory Quality
#   62  International Comparison Program (ICP) 2011
#   63  Human Capital Index
#   64  Worldwide Bureaucracy Indicators
#   65  Health Equity and Financial Protection Indicators
#   66  Logistics Performance Index
#   67  PEFA 2011
#   68  PEFA 2016
#   69  Global Financial Inclusion and Consumer Protection Survey
#   70  Economic Fitness 2
#   71  International Comparison Program (ICP) 2005
#   73  Global Financial Inclusion and Consumer Protection Survey (Internal)
#   75  Environment, Social and Governance (ESG) Data
#   76  Remittance Prices Worldwide (Sending Countries)
#   77  Remittance Prices Worldwide (Receiving Countries)
#   78  ICP 2017
#   79  PEFA_GRPFM
#   80  Gender Disaggregated Labor Database (GDLD)
#   81  International Debt Statistics: DSSI
#   82  Global Public Procurement
#   83  Statistical Performance Indicators (SPI)
#   84  Education Policy
#   85  PEFA_2021_SNG
#   86  Global Jobs Indicators Database (JOIN)
#   87  Country Climate and Development Report (CCDR)
#   88  Food Prices for Nutrition
#   89  Identification for Development (ID4D) Data
#   90  ICP 2021
#   91  PEFA_CRPFM
#   92  Disability Data Hub (DDH)

# %%
#Dentro de los parametros, elegimos trabajar con "Health Nutrition and Population Statistics" y centrarnos en "Rural population (% of total population)" y "Urban population (% of total population)"
wbdata.get_indicators(source=16, query="Rural population"), wbdata.get_indicators(source=16, query="Urban population")
# Out:
# (id                 name
#  -----------------  ------------------------------------------------------------------------------------------------
#  SH.H2O.BASW.RU.ZS  People using at least basic drinking water services, rural (% of rural population)
#  SH.H2O.SMDW.RU.ZS  People using safely managed drinking water services, rural (% of rural population)
#  SH.STA.BASS.RU.ZS  People using at least basic sanitation services, rural (% of rural population)
#  SH.STA.HYGN.RU.ZS  People with basic handwashing facilities including soap and water, rural (% of rural population)
#  SH.STA.ODFC.RU.ZS  People practicing open defecation, rural (% of rural population)
#  SH.STA.SMSS.RU.ZS  People using safely managed sanitation services, rural (% of rural population)
#  SI.POV.RUHC        Rural poverty headcount ratio at national poverty lines (% of rural population)
#  SP.RUR.TOTL        Rural population
#  SP.RUR.TOTL.ZG     Rural population growth (annual %)
#  SP.RUR.TOTL.ZS     Rural population (% of total population),
#  id                 name
#  -----------------  ------------------------------------------------------------------------------------------------
#  SH.H2O.BASW.UR.ZS  People using at least basic drinking water services, urban (% of urban population)
#  SH.H2O.SMDW.UR.ZS  People using safely managed drinking water services, urban (% of urban population)
#  SH.STA.BASS.UR.ZS  People using at least basic sanitation services, urban (% of urban population)
#  SH.STA.HYGN.UR.ZS  People with basic handwashing facilities including soap and water, urban (% of urban population)
#  SH.STA.ODFC.UR.ZS  People practicing open defecation, urban (% of urban population)
#  SH.STA.SMSS.UR.ZS  People using safely managed sanitation services, urban (% of urban population)
#  SI.POV.URHC        Urban poverty headcount ratio at national poverty lines (% of urban population)
#  SP.URB.GROW        Urban population growth (annual %)
#  SP.URB.TOTL        Urban population
#  SP.URB.TOTL.IN.ZS  Urban population (% of total population))

# %%
# Obtener los datos de porcentaje de población urbana y rural
wbdata.get_data("SP.URB.TOTL.IN.ZS", country=["AUS", "CHN"]), wbdata.get_data("SP.RUR.TOTL.ZS", country=["AUS", "CHN"])
# Out:
# ([{'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2023',
#    'value': 86.617,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2022',
#    'value': 86.488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2021',
#    'value': 86.362,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2020',
#    'value': 86.241,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2019',
#    'value': 86.124,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2018',
#    'value': 86.012,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2017',
#    'value': 85.904,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2016',
#    'value': 85.8,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2015',
#    'value': 85.701,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2014',
#    'value': 85.602,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2013',
#    'value': 85.502,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2012',
#    'value': 85.402,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2011',
#    'value': 85.3,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2010',
#    'value': 85.182,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2009',
#    'value': 85.063,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2008',
#    'value': 84.943,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2007',
#    'value': 84.822,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2006',
#    'value': 84.7,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2005',
#    'value': 84.582,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2004',
#    'value': 84.463,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2003',
#    'value': 84.343,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2002',
#    'value': 84.222,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2001',
#    'value': 84.1,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2000',
#    'value': 84.235,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1999',
#    'value': 84.37,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1998',
#    'value': 84.503,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1997',
#    'value': 84.636,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1996',
#    'value': 84.767,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1995',
#    'value': 84.898,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1994',
#    'value': 85.028,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1993',
#    'value': 85.157,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1992',
#    'value': 85.285,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1991',
#    'value': 85.403,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1990',
#    'value': 85.433,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1989',
#    'value': 85.463,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1988',
#    'value': 85.493,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1987',
#    'value': 85.522,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1986',
#    'value': 85.552,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1985',
#    'value': 85.582,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1984',
#    'value': 85.611,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1983',
#    'value': 85.641,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1982',
#    'value': 85.67,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1981',
#    'value': 85.7,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1980',
#    'value': 85.552,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1979',
#    'value': 85.403,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1978',
#    'value': 85.252,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1977',
#    'value': 85.1,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1976',
#    'value': 84.947,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1975',
#    'value': 84.792,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1974',
#    'value': 84.636,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1973',
#    'value': 84.478,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1972',
#    'value': 84.32,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1971',
#    'value': 84.16,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1970',
#    'value': 83.999,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1969',
#    'value': 83.836,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1968',
#    'value': 83.672,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1967',
#    'value': 83.507,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1966',
#    'value': 83.34,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1965',
#    'value': 83.068,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1964',
#    'value': 82.792,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1963',
#    'value': 82.511,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1962',
#    'value': 82.228,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1961',
#    'value': 81.941,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '1960',
#    'value': 81.529,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2023',
#    'value': 64.57,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2022',
#    'value': 63.56,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2021',
#    'value': 62.512,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2020',
#    'value': 61.428,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2019',
#    'value': 60.308,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2018',
#    'value': 59.152,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2017',
#    'value': 57.96,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2016',
#    'value': 56.736,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2015',
#    'value': 55.5,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2014',
#    'value': 54.259,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2013',
#    'value': 53.013,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2012',
#    'value': 51.765,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2011',
#    'value': 50.511,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2010',
#    'value': 49.226,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2009',
#    'value': 47.88,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2008',
#    'value': 46.539,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2007',
#    'value': 45.199,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2006',
#    'value': 43.868,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2005',
#    'value': 42.522,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.URB.TOTL.IN.ZS',
#     'value': 'Urban population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '2004',
#    

#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1981',
#    'value': 79.882,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1980',
#    'value': 80.642,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1979',
#    'value': 81.383,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1978',
#    'value': 82.1,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1977',
#    'value': 82.48,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1976',
#    'value': 82.54,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1975',
#    'value': 82.6,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1974',
#    'value': 82.708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1973',
#    'value': 82.816,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1972',
#    'value': 82.816,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1971',
#    'value': 82.708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1970',
#    'value': 82.6,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1969',
#    'value': 82.472,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1968',
#    'value': 82.344,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1967',
#    'value': 82.215,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1966',
#    'value': 82.085,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1965',
#    'value': 81.914,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1964',
#    'value': 81.701,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1963',
#    'value': 82.243,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1962',
#    'value': 82.774,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1961',
#    'value': 83.292,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.RUR.TOTL.ZS',
#     'value': 'Rural population (% of total population)'},
#    'country': {'id': 'CN', 'value': 'China'},
#    'countryiso3code': 'CHN',
#    'date': '1960',
#    'value': 83.797,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}])

# %%
# Definir los paises e indicador
paises = ["AUS", "CHN"]
indicadorU = {
    "SP.URB.TOTL.IN.ZS": "Urban Population (%)"}
indicadorR = {
    "SP.RUR.TOTL.ZS": "Rural Population (%)"}

# Obtener los datos en formato DataFrame
dfU = wbdata.get_dataframe(indicadorU, country=paises, date=("2005","2020"))

# Reorganizar la tabla para que cada pais tenga sus propias columnas
dfU = dfU.unstack(level=1)  # Pone los paises en columnas
dfU=dfU.round(1)
# Mostrar las tablas
display(dfU)
dfR = wbdata.get_dataframe(indicadorR, country=paises, date=("2005","2020"))
dfR = dfR.unstack(level=1)  
dfR=dfR.round(1)
display(dfR)
# Out:
#           Urban Population (%)                                            \
# date                      2005  2006  2007  2008  2009  2010  2011  2012
# country
# Australia                 84.6  84.7  84.8  84.9  85.1  85.2  85.3  85.4
# China                     42.5  43.9  45.2  46.5  47.9  49.2  50.5  51.8
#
#
# date       2013  2014  2015  2016  2017  2018  2019  2020
# country
# Australia  85.5  85.6  85.7  85.8  85.9  86.0  86.1  86.2
# China      53.0  54.3  55.5  56.7  58.0  59.2  60.3  61.4
#           Rural Population (%)                                            \
# date                      2005  2006  2007  2008  2009  2010  2011  2012
# country
# Australia                 15.4  15.3  15.2  15.1  14.9  14.8  14.7  14.6
# China                     57.5  56.1  54.8  53.5  52.1  50.8  49.5  48.2
#
#
# date       2013  2014  2015  2016  2017  2018  2019  2020
# country
# Australia  14.5  14.4  14.3  14.2  14.1  14.0  13.9  13.8
# China      47.0  45.7  44.5  43.3  42.0  40.8  39.7  38.6

# %% [markdown]
# #### Ejercicio 2 - Repaso de Pandas
# Realicen una estadistica descriptiva de ambas series de indicadores comparando los dos países.

# %%
#Calculamos el desvio
dvU = dfU.std(axis=1).round(2)
dvR=dfR.std(axis=1).round(2)
#Calculamos la media
mdU=dfU.mean(axis=1).round(2)
mdR=dfR.mean(axis=1).round(2)
#Calculamos el coeficiente de variacion
cvU=((dvU/mdU)*100).round(2)
cvR=((dvR/mdR)*100).round(2)
data={
    "Coeficiente de Variacion(%) Poblacion Urbana":cvU.values,
    "Coeficiente de Variacion(%) Poblacion Rural":cvR.values
}
dfcv= pd.DataFrame(data, index=cvU.index)   
    
    
#Mostramos los resultados
display(dfcv)
# Out:
#            Coeficiente de Variacion(%) Poblacion Urbana  \
# country
# Australia                                          0.60
# China                                             11.52
#
#            Coeficiente de Variacion(%) Poblacion Rural
# country
# Australia                                          3.5
# China                                             12.6

# %% [markdown]
# #### Ejercicio 3 - Practicando con Matplotlib
# Armen dos gráficos distintos usando la librería Matplotlib (repasen Clase 4). Uno programandolo con el estilo *pyplot* y otro gráfico de estilo *orientada a objetos*

# %%
# Resolver acá estilo pyplot
# Extraer años de las columnas (el segundo nivel del MultiIndex)
años = [str(año) for año in range(2005, 2021)]  # De 2005 a 2020

# Inicializar listas para almacenar los datos de Australia y China
datos_aus = []
datos_chn = []

# Recorremos los años y extraemos los datos correspondientes para Australia y China
for año in años:
    # Acceder a las columnas con el formato correcto
    columna = ('Urban Population (%)', año)  # Crear la tupla para el MultiIndex
    
    # Obtener los valores para Australia y China de esa columna
    datos_aus.append(dfU[columna]['Australia'])
    datos_chn.append(dfU[columna]['China'])

# Crear el gráfico
plt.style.use('default')
plt.figure(figsize=(10, 6))

# Graficar los datos de Australia y China
plt.plot(años, datos_aus, label='Australia', marker='o', color='b')
plt.plot(años, datos_chn, label='China', marker='o', color='r')

# Agregar títulos y etiquetas
plt.title("Evolución de la Población Urbana: Australia vs China (2005-2020)", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Porcentaje de Población Urbana (%)", fontsize=12)
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %%
# Resolver acá estilo orientado-objetos 
# Tip: aprovechar este estilo de programar una figura para hacerlo más lindo 
# Transponer para que los años pasen a ser el índice
df_rural_t = dfR.T  # Transpone el dataframe

# Eliminar el primer nivel del MultiIndex de las columnas (si solo hay una variable)
df_rural_t.index = df_rural_t.index.droplevel(0)

# Ahora los países están como columnas y los años como índice
df_rural_t.index.name = "Año"
df_rural_t.columns.name = "País"

# Transponer el DataFrame de población urbana para que los años sean el índice
df_urbana_t = dfU.T  
df_urbana_t.index = df_urbana_t.index.droplevel(0)  # Eliminar primer nivel del MultiIndex
df_urbana_t.index.name = "Año"  # Etiqueta para el índice
df_urbana_t.columns.name = "País"  # Etiqueta para las columnas

# Estilo visual
plt.style.use("dark_background")

# Crear figura y ejes
fig, ax = plt.subplots(2, 2, figsize=(12, 8))

# Seleccionar los ejes que se van a usar
ejes = [ax[0, 0], ax[0, 1]]
paises = ["Australia", "China"]

# Colores y marcadores para rural y urbana
colores = {
    "Rural": "white",
    "Urbana": "tomato"
}
marcadores = {
    "Rural": "o",
    "Urbana": "s"
}

# Graficar por país
for i, pais in enumerate(paises):
    # Población rural
    ejes[i].plot(
        df_rural_t.index, df_rural_t[pais],
        label="Rural",
        color=colores["Rural"],
        marker=marcadores["Rural"],
        linewidth=2.5,
        markersize=6
    )
    
    # Población urbana
    ejes[i].plot(
        df_urbana_t.index, df_urbana_t[pais],
        label="Urbana",
        color=colores["Urbana"],
        marker=marcadores["Urbana"],
        linewidth=2.5,
        markersize=6
    )

    # Personalización
    ejes[i].set_title(f"Población Rural vs Urbana en {pais}", fontsize=14, weight='bold')
    ejes[i].set_xlabel("Año", fontsize=12)
    ejes[i].set_ylabel("Porcentaje (%)", fontsize=12)
    ejes[i].tick_params(axis='x', labelsize=8)
    ejes[i].set_ylim(0, 100)
    ejes[i].grid(True, linestyle="--", alpha=0.5)
    ejes[i].legend(title="Tipo de Población", fontsize=10, facecolor="black", edgecolor="white", framealpha=1, frameon=True)
    

# Eliminar los subgráficos no usados
fig.delaxes(ax[1, 0])
fig.delaxes(ax[1, 1])

# Título general
plt.suptitle("Comparación Población Rural y Urbana (2005–2020)", fontsize=16, weight='bold', y=1.03)

# Ajustar espaciado
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 4
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/) o cualquier diario que les interese, utilicen herramientas de web scraping para obtener los **links** de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from unidecode import unidecode  # Para eliminar acentos

# URL de Infobae
URL = "https://www.infobae.com"

# Descargar la página
pag = requests.get(URL)
contenido = pag.content

# Analizar con BeautifulSoup
soup = BeautifulSoup(contenido, "html.parser")

# Extraer los títulos de las noticias
titulos = [h2.get_text().strip() for h2 in soup.find_all('h2', class_="story-card-hl headline-link")]

# Extraer los links de las noticias
Links_elements = soup.find_all('a', href=True)
Links = []

for t in Links_elements:
    Link = t['href']

    # Si el enlace es relativo, lo convertimos en absoluto
    if Link.startswith('/'):
        Link = URL + Link

    # Extraer la última parte de la URL (slug) y separar en palabras
    partes_link = [unidecode(p.lower()) for p in Link.rstrip('/').split("/")[-1].split("-")]

    for titulo in titulos:
        palabras_titulo = [unidecode(p.lower()) for p in titulo.strip().split()]
        
        # Si el título contiene "Javier Milei", agregue este filtro ya que Javier Milei tiene su propio apartado en Infobae
        if "javier" in palabras_titulo and "milei" in palabras_titulo:
            if "javier" in partes_link and "milei" in partes_link:
                # Buscar una tercera palabra del título que también esté en el link
                otra_palabra = next(
                    (p for p in palabras_titulo if p not in ["javier", "milei"] and p in partes_link),
                    None
                )
                if otra_palabra:
                    print("Coincidencia encontrada (Javier Milei + otra palabra):", titulo)
                    Links.append({'Título': titulo, 'Link': Link})
                    break  # Evita agregar el mismo link más de una vez
        else:
            # Comparación con la primera palabra normalizada
            primera_palabra_titulo = palabras_titulo[0] if palabras_titulo else ""
            primera_palabra_link = partes_link[0] if partes_link else ""

            if primera_palabra_titulo == primera_palabra_link:
                print("Coincidencia encontrada:", titulo)
                Links.append({'Título': titulo, 'Link': Link})
                break  # Evita agregar el mismo link más de una vez

# Crear DataFrame con los links filtrados
DfL = pd.DataFrame(Links)

# 🔹 **Eliminar duplicados por título**
DfL = DfL.drop_duplicates(subset=["Título"], keep="first").reset_index(drop=True)

# Mostrar el DataFrame
display(DfL)

# Guardar en Excel
DfL.to_excel('Noticias_filtradas.xlsx', index=False)
print("Archivo de Excel guardado como 'Noticias_filtradas.xlsx'")
# Out:
# ✅ Coincidencia encontrada (Javier Milei + otra palabra): Javier Milei dijo que Argentina readecuará su legislación para atenuar el impacto de los aranceles de Trump
# Coincidencia encontrada: Con votos del PRO y el kirchnerismo, el Senado rechazó las candidaturas de Ariel Lijo y García-Mansilla a la Corte Suprema
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
# Coincidencia encontrada: Crónica de una muerte anunciada
# Coincidencia encontrada: Uno por uno, cómo votaron los senadores los pliegos de Ariel Lijo y García-Mansilla a la Corte Suprema
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: Alpine confirmó cuándo regresará Colapinto a un GP: su plan de trabajo para volver a correr en F1
# Coincidencia encontrada: Un banco tradicional lanza por primera vez una cuenta remunerada en pesos y en dólares: cómo funciona
# Coincidencia encontrada: Con votos del PRO y el kirchnerismo, el Senado rechazó las candidaturas de Ariel Lijo y García-Mansilla a la Corte Suprema
# Coincidencia encontrada
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: Dua Lipa anunció su show más grande en Argentina: cómo fueron sus últimas visitas y su relación con el país
# Coincidencia encontrada: Juanita Tinelli negó los rumores de ruptura y contó cómo es su relación con Milett Figueroa: "Lo que más me molestó"
# Coincidencia encontrada: Un banco tradicional lanza por primera vez una cuenta remunerada en pesos y en dólares: cómo funciona
# Coincidencia encontrada: Las farmacias deberán exhibir un código QR con la lista de precios de los medicamentos
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: Arranca en Córdoba "Capital Feria", la primera iniciativa de arte privada por fuera de CABA
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: Un banco tradicional lanza por primera vez una cuenta remunerada en pesos y en dólares: cómo funciona
# ✅ Coincidencia encontrada (Javier Milei + otra palabra): Javier Milei dijo que Argentina readecuará su legislación para atenuar el impacto de los aranceles de Trump
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: Condenaron a 13 años de prisión a Mario Segovia, “el Rey de la Efedrina” por liderar una asociación ilícita desde el penal de Ezeiza
# Coincidencia encontrada: Crónica de una muerte anunciada
# Coincidencia encontrada: Uno por uno, cómo votaron los senadores los pliegos de Ariel Lijo y García-Mansilla a la Corte Suprema
# Coincidencia encontrada: Peter Lanzani habló del robo que sufrió en Neuquén y dio detalles del momento que vivió: “Me rompieron el vidrio”
# Coincidencia encontrada: Tini Stoessel terminó con el misterio: de qué se trata su próximo proyecto “Futttura”
# Coincidencia encontrada: Tini Stoessel terminó con el misterio: de qué se trata su próximo proyecto “Futttura”
# Coincidencia encontrada: Inminente anuncio de Tini Stoessel y Rodrigo De Paul acerca de su relación
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
# Coincidencia encontrada: El juez Ramos Padilla le ordenó a García-Mansilla que se abstenga de firmar nuevos fallos en la Corte
# Coincidencia encontrada: La dignidad republicana y el deber de renunciar ante el rechazo del Senado
#                                                Título  \
# 0   Javier Milei dijo que Argentina readecuará su ...
# 1   Con votos del PRO y el kirchnerismo, el Senado...
# 2   El juez Ramos Padilla le ordenó a García-Mansi...
# 3   La dignidad republicana y el deber de renuncia...
# 4                     Crónica de una muerte anunciada
# ..                                                ...
# 57  Kevin Bacon regresa a la pantalla chica con “C...
# 58  Se cumplen 40 años del estreno de La historia ...
# 59  Dua Lipa anunció su show más grande en Argenti...
# 60  Juanita Tinelli negó los rumores de ruptura y ...
# 61  Arranca en Córdoba "Capital Feria", la primera...
#
#                                                  Link
# 0   https://www.infobae.com/politica/2025/04/04/ja...
# 1   https://www.infobae.com/politica/2025/04/03/co...
# 2   https://www.infobae.com/judiciales/2025/04/04/...
# 3   https://www.infobae.com/opinion/2025/04/03/la-...
# 4   https://www.infobae.com/opinion/2025/04/04/cro...
# ..                                                ...
# 57  https://www.infobae.com/que-puedo-ver/2025/04/...
# 58  https://www.infobae.com/teleshow/2025/04/03/se...
# 59  https://www.infobae.com/teleshow/2025/04/02/du...
# 60  https://www.infobae.com/teleshow/2025/04/02/ju...
# 61  https://www.infobae.com/cultura/2025/04/03/arr...
#
# [62 rows x 2 columns]
# Archivo de Excel guardado como 'Noticias_filtradas.xlsx'
